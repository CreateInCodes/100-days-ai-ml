# %% [markdown]
# # Tentative plan

# %%
# 1. Python Essentials --> 12
# 2. Python for AI & ML --> 12
# 3. SQL for ML & AI -->> Structured Query Language --> 18
# 4. Numpy --> Python Library for Numerical Python  -->6
# 5. EDA using Pandas --> Efficiently deal with Tabular data using Python --> 12
# 6. Data Visulization using Python --> Matpotlib, Seaborn --> 6
# 7. Probabilty & Statistics --> 12
# 8. Classical ML --> Classifiction, Regression --> 12
# 9. Deep Learning --> Neural Networks --> 12
# 10. GenAI & Prompt Engineering --> LLM, Frameworks for Prompt Engineering --> 16
# 11. RAG, Agents, MCP --> 16
# 12. Project & Deployment --> 5

# %% [markdown]
# ## Programming --> Giving Instructions and Interacting with the Computer

# %% [markdown]
# # Imprtant Terminologies

# %%
# Algorithm --> step by step instructions to solve any problem.

# Programming --> is a way of writing these instructions in alnguage that the computer understandas.

# Programming Languages --> C, C++, Python, Java, JavaScript

# Why Python?...>
# 1. Easy to understand -->programmer friendly
# 2. Rich set of Libraries --> AI, ML, Web Dev, Automation...


# Hello world program --> c++ and Python

# C++:

# #include<iostream>
# using namespace std;

# int main(){
#     cout<<"Hello World";
# }

# Python:
# print("Hello world")

# "Apple is Sameer an eating"
# --------------
# "Sameer is eating an apple"

# What is Syntax?
# - Grammatical rules for that particular programming language is called syntax.


# Why Google Colab Notebook
# 1. No installation
# 2. Free
# 3. Runs in Browser
# 4. Used across industry

# %% [markdown]
# # Basics of Python Programming

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("Welcome to Python")
# Out:
# Welcome to Python

# %%
print("A")
print("B")
print("C")
# Out:
# A
# B
# C

# %%
print("A", "B", "C")
# Out:
# A B C

# %%
print(100)
# Out:
# 100

# %%
print(3+5)
# Out:
# 8

# %%
print(3-5)
# Out:
# -2

# %%
print(4/2)
# Out:
# 2.0

# %%
print(5%2)
# Out:
# 1

# %%
print("3+2")
# Out:
# 3+2

# %% [markdown]
# #Quizes
